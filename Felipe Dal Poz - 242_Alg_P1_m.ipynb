# %% [markdown]
# ##**P1 - 2º. semestre/2024 -  Término: 12:00**
# ##HOJE EU NÃO VERIFICO A LÓGICA/PROGRAMAÇÃO, NEM ERROS DE CÓDIGO, POIS É UMA PROVA DE CONSULTA.
#
# ##>>>>>>>>>>> Não use os recurso de IA do Colab <<<<<<<<<<<<
#
# ## É uma prova de consulta ao seu material, **apenas use os slides da disciplina de Algoritmo e as listas de exercícios do Colab da nossa aula**.
#
# ##Caso entregue atrasado não será aceita a prova. **O Classroom/Collab NÃO DEIXA ENTREGAR FORA DO PRAZO**.
#
# ##Depois de terminada a prova, **você NÃO PODE** MAIS ALTERAR O ARQUIVO DELA, essa ação fica registrada e assim a prova será **ANULADA**.
#
# ##Na próxima aula, na próxima semana será realizada a correção da prova.
#
# ##**Não é permitido o acesso a qualquer outro site/aplicativo para o desenvolvimento da prova, ou seja, apenas poderão estar abertas e visíveis as guias (no navegador de internet) do Classroom e Colab.**
#
# #Não é permitido o uso do celular no dia da prova.
#
# #CASO VERIFIQUE QUE O COLLAB TENHA ALGUM PROBLEMA, VÁ NO MENU, NA OPÇÃO DE AMBIENTE DE EXECUÇÃO, ESCOLHA A OPÇÃO REINICIAR SESSÃO, CLIQUE EM SIM E TENTE EXECUTAR NOVAMENTE O SEU PROGRAMA.
# ______________________________________________________

# %% [markdown]
# ##**1.** [1,0 ponto - **Entrada, processamento e saída**] Desenvolva um programa, utilizando a linguagem Python, que leia um preço de um ingresso de um show e a porcentagem de desconto, calcule e apresente o valor do *desconto* e o preço final do ingresso após o desconto.
#
# ##**Observação**: Não use estrutura de repetição, vetor, matriz, def de Python.

# %%
# Implemente seu programa aqui
# Não use os recurso de IA do Colab, será anulada a questão
# Desligue: vá em configurações, assistente de IA, escolha "Ocultar recursos de IA generativa"
p=float(input('Informe o preço do seu ingresso '))
d=float(input('Informe o seu desconto '))
po= p/100
pi=po*d
pf=p-pi
print(f'Preço do seu desconto no ingresso é de R${pi:.2f}')
print(f'Preço final do seu ingresso é de R${pf:.2f}')
# Out:
# Informe o preço do seu ingresso 100
# Informe o seu desconto 0
# Preço do seu desconto no ingresso é de R$0.00
# Preço final do seu ingresso é de R$100.00

# %% [markdown]
# ##**2.** [2,5 pontos - **Estrutura de decisão**] Desenvolva um programa, utilizando a linguagem Python,  que realize algumas opções:
# ###a) Construa o menu a seguir do exemplo, com o comando print;
#
# ###b) Digite três valores, conforme apresentado no menu.
#
# ###c) Desenvolva os cálculos e apresente os resultados, dentro da opção escolhida pelo usuário.
# ......................................................................................................................
#
# ###    Menu de opções
# ###    Digite um preço...............:
# ###    Digite a porcentagem..........:
# ###    Digite a quantidade de pessoas:
# .....................................................................
# ###        1 - Valor do desconto
# ###        2 - Valor do ingresso após desconto para uma pessoa
# ###        3 - Valor total do ingresso para a quantidade informada
# ###    Qual opção deseja?
# ......................................................................................................................
#
# ###**Observação**: Não use estrutura de repetição, vetor, matriz, def ou qualquer função pronta de Python.

# %%
# Implemente seu programa aqui
# Não use os recurso de IA do Colab, será anulada a questão
# Desligue: vá em configurações, assistente de IA, escolha "Ocultar recursos de IA generativa"
print('Digite "1" para saber o valor do deconto')
print('Digite "2" para saber o valor do ingresso com desconto')
print('Digite "3" Valor total dos ingressos vendidos para a quantidade de pessoas informada')
n=int(input('Qual opção deseja? '))
p=float(input('Informe o preço do seu ingresso '))
d=float(input('Informe o desconto '))
po = p / 100 #valor de 1%
pi = po * d
pf = p - pi
if n == 3:
    i=float(input('Informe quantas pessoas foram '))
    inf=i*pf
    print(f'Valor total arrecadado dos ingressos para a quantidade informada é de R${inf:.2f}')
elif n == 2:
    print(f'Preço final do seu ingresso é de R${pf:.2f}')
elif n == 1:
    print(f'Preço do seu desconto no ingresso é de R${pi:.2f}')
else:
    print('erro')
# Out:
# Digite "1" para saber o valor do deconto
# Digite "2" para saber o valor do ingresso com desconto
# Digite "3" Valor total dos ingressos vendidos para a quantidade de pessoas informada
# Qual opção deseja? 2
# Informe o preço do seu ingresso 100
# Informe o desconto 10
# Preço final do seu ingresso é de R$90.00

# %% [markdown]
# ##**3.**  [3,5 pontos - **Estrutura de repetição**] Desenvolva um programa, utilizando a linguagem Python, que leia o valor da mensalidade paga de 200 alunos de uma academia. Tem aluno que não tem condições de pagar, então digite zero. Calcule e apresente:
# ##a) a quantidade de mensalidades pagas
# ##b) a quantidade de mulheres
# ##c) a quantidade de homens
# ##d) total de mensalidades pagas
#
# ##**Observação**: Não vetor, matriz, def ou qualquer função pronta de Python.

# %%
# Implemente seu programa aqui
# Não use os recurso de IA do Colab, será anulada a questão
# Desligue: vá em configurações, assistente de IA, escolha "Ocultar recursos de IA generativa"
total_mulheres = 0
total_homens = 0
p1 = 0
pf = 0
p0 = 0
for aluno in range(200):
    genero = input('Cadastre o gênero (M/F): ')

    if genero == 'F' or genero == 'f':
        total_mulheres = total_mulheres + 1
    elif genero == 'M' or genero == 'm':
        total_homens = total_homens + 1

    p= float(input('Qual sua mensalidade? '))
    pf = pf + p
    if p > 0:
        p1 = p1 + 1
    elif p <= 0:
        p0 = p0 + 1

print("Total de homens no curso:", total_homens)
print("Total de mulheres no curso:", total_mulheres)
print('Total de pessoas quem pagam mensalidade',p1)
print(f'Todo dinheiro que foi ganho por mensalidades, foi o valor de R${pf:.2f}')
# Out:
# Cadastre o gênero (M/F): m
# Qual sua mensalidade? 1
# Cadastre o gênero (M/F): m
# Qual sua mensalidade? 0
# Cadastre o gênero (M/F): f
# Qual sua mensalidade? 1
# Cadastre o gênero (M/F): f
# Qual sua mensalidade? 1
# Cadastre o gênero (M/F): m
# Qual sua mensalidade? 1
# Total de homens no curso: 3
# Total de mulheres no curso: 2
# Total de pessoas quem pagam mensalidade 4
# Todo dinheiro que foi ganho por mensalidades, foi o valor de R$4.00
